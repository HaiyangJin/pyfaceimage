# %%
import pyfaceimage as fim

import os
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Read images

# %%
# create instances
color = fim.image('im/color.png', read=True)
rgba = fim.image('im/rgba.png', read=True)
rgb = fim.image('im/rgb.png', read=True)
ga = fim.image('im/ga.png', read=True)
g = fim.image('im/g.png', read=True)

# %%
# tests
assert rgba.file==os.path.join(os.getcwd(), 'im/rgba.png')
assert rgba.fn=='rgba.png'
assert rgba.fnonly=='rgba'
assert rgba.ext=='.png'
assert rgba.dir==os.path.join(os.getcwd(), 'im')
assert rgba.group=='im'
assert rgba.isfile==1

assert rgba.nlayer==4
assert rgb.nlayer==3
assert ga.nlayer==2
assert g.nlayer==0

# %% [markdown]
# # Adjusting image luminance

# %%
rgb1 = rgb.deepcopy()
rgb1.pil
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=200x256 at 0x1105A5FA0>

# %%
rgb1.adjust(0.1)
rgb1.pil
# Out:
# <PIL.Image.Image image mode=L size=200x256 at 0x10D766280>

# %% [markdown]
# # Padding

# %%
# original image
rgba.pil
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=200x256 at 0x10C552AF0>

# %%
rgba_pad = rgba.deepcopy()
rgba_pad.pad(trgw=600, trgh=350)
rgba_pad.pil
# Out:
# <PIL.Image.Image image mode=RGBA size=600x350 at 0x10F869190>

# %%
# padding background is white (default)
rgb_pad = rgb.deepcopy()
rgb_pad.pad(trgw=600, trgh=350)
rgb_pad.pil
# Out:
# <PIL.Image.Image image mode=RGB size=600x350 at 0x10F7FBC10>

# %%
# padding background is white
rgb_pad = rgb.deepcopy()
rgb_pad.pad(trgw=600, trgh=350, padvalue=255)
rgb_pad.pil
# Out:
# <PIL.Image.Image image mode=RGB size=600x350 at 0x10EA0E3A0>

# %%
ga_pad = ga.deepcopy()
ga_pad.pad(trgw=600, trgh=350)
ga_pad.pil
# Out:
# <PIL.Image.Image image mode=LA size=600x350 at 0x10F581AC0>

# %%
# with transparent padding background (default)
g_pad = g.deepcopy()
g_pad.pad(trgw=600, trgh=350)
g_pad.pil
# Out:
# <PIL.Image.Image image mode=L size=600x350 at 0x10F581A90>

# %%
# padding background is white
g_pad = g.deepcopy()
g_pad.pad(trgw=600, trgh=350, padvalue=255)
g_pad.pil
# Out:
# <PIL.Image.Image image mode=L size=600x350 at 0x10F8342E0>

# %%
# force the background to be transparent
rgba_pad = rgba.deepcopy()
rgba_pad.pad(trgw=600, trgh=350, alphavalue=255)
rgba_pad.pil
# Out:
# <PIL.Image.Image image mode=RGBA size=600x350 at 0x10EB15EB0>

# %%
# force the background to be transparent
rgb_pad = rgb.deepcopy()
rgb_pad.pad(trgw=600, trgh=350, alphavalue=255)
rgb_pad.pil
# Out:
# <PIL.Image.Image image mode=RGB size=600x350 at 0x10F5692B0>

# %%
# force the background to be transparent
ga_pad = ga.deepcopy()
ga_pad.pad(trgw=600, trgh=350, alphavalue=255)
ga_pad.pil
# Out:
# <PIL.Image.Image image mode=LA size=600x350 at 0x10F523340>

# %%
# force the background to be transparent
g_pad = g.deepcopy()
g_pad.pad(trgw=600, trgh=350, alphavalue=255)
g_pad.pil
# Out:
# <PIL.Image.Image image mode=L size=600x350 at 0x10F581F40>

# %% [markdown]
# # Box scrambled

# %% [markdown]
# ## By setting number of boxes

# %%
rgba_bs = rgba.deepcopy()
rgba_bs.mkboxscr()
rgba_bs.pil
# Out:
# <PIL.Image.Image image mode=RGBA size=200x256 at 0x10F7F28E0>

# %%
rgb_bs = rgb.deepcopy()
rgb_bs.mkboxscr()
rgb_bs.pil
# Out:
# <PIL.Image.Image image mode=RGB size=200x256 at 0x10F834340>

# %%
ga_bs = ga.deepcopy()
ga_bs.mkboxscr()
ga_bs.pil
# Out:
# <PIL.Image.Image image mode=LA size=200x256 at 0x10F7F2820>

# %%
g_bs = g.deepcopy()
g_bs.mkboxscr()
g_bs.pil
# Out:
# <PIL.Image.Image image mode=L size=200x256 at 0x10F569310>

# %% [markdown]
# ## By setting the pixels of boxes

# %%
rgba_bs = rgba.deepcopy()
rgba_bs.mkboxscr(pBoxW=10, pBoxH=8)
rgba_bs.pil
# Out:
# <PIL.Image.Image image mode=RGBA size=200x256 at 0x10F7FB190>

# %%
rgb_bs = rgb.deepcopy()
rgb_bs.mkboxscr(pBoxW=10, pBoxH=8)
rgb_bs.pil
# Out:
# <PIL.Image.Image image mode=RGB size=200x256 at 0x10F7F23D0>

# %%
ga_bs = ga.deepcopy()
ga_bs.mkboxscr(pBoxW=10, pBoxH=8)
ga_bs.pil
# Out:
# <PIL.Image.Image image mode=LA size=200x256 at 0x10C552D00>

# %%
g_bs = g.deepcopy()
g_bs.mkboxscr(pBoxW=10, pBoxH=8)
g_bs.pil
# Out:
# <PIL.Image.Image image mode=L size=200x256 at 0x10F7F2730>

# %% [markdown]
# ## By setting number of boxes with makingup

# %%
nBoxW, nBoxH = 21, 20

rgba_bs = rgba.deepcopy()
rgba_bs.mkboxscr(nBoxW=nBoxW, nBoxH=nBoxH, pad=True)

assert rgba_bs.h == np.ceil(rgba.h/nBoxH)*nBoxH
assert rgba_bs.w == np.ceil(rgba.w/nBoxW)*nBoxW

rgba_bs.pil
# Out:
# <PIL.Image.Image image mode=RGBA size=210x260 at 0x10C552E50>

# %%
rgb_bs = rgb.deepcopy()
rgb_bs.mkboxscr(nBoxW=nBoxW, nBoxH=nBoxH, pad=True)
rgb_bs.pil
# Out:
# <PIL.Image.Image image mode=RGB size=210x260 at 0x10F873DC0>

# %%
ga_bs = ga.deepcopy()
ga_bs.mkboxscr(nBoxW=nBoxW, nBoxH=nBoxH, pad=True)
ga_bs.pil
# Out:
# <PIL.Image.Image image mode=LA size=210x260 at 0x10F7F2790>

# %%
g_bs = g.deepcopy()
g_bs.mkboxscr(nBoxW=nBoxW, nBoxH=nBoxH, pad=True)
g_bs.pil
# Out:
# <PIL.Image.Image image mode=L size=210x260 at 0x10F569220>

# %% [markdown]
# ## By setting box pixels with making up

# %%
pBoxW, pBoxH = 9, 13
rgba_bs = rgba.deepcopy()
rgba_bs.mkboxscr(pBoxW=pBoxW, pBoxH=pBoxH, pad=True)

assert rgba_bs.h == np.ceil(rgba.h/pBoxH)*pBoxH
assert rgba_bs.w == np.ceil(rgba.w/pBoxW)*pBoxW

rgba_bs.pil
# Out:
# <PIL.Image.Image image mode=RGBA size=207x260 at 0x10F5B6940>

# %% [markdown]
# # Re-size images

# %%
rgba_resize = rgba.deepcopy()
rgba_resize.resize(trgw=300)

assert rgba_resize.h==384
assert rgba_resize.nlayer==4

rgba_resize.pil
# Out:
# <PIL.Image.Image image mode=RGBA size=300x384 at 0x10F8AFD60>

# %%
rgb_resize = rgb.deepcopy()
rgb_resize.resize(trgh=384)

assert rgb_resize.w==300
assert rgb_resize.nlayer==3

rgb_resize.pil
# Out:
# <PIL.Image.Image image mode=RGB size=300x384 at 0x10F8343A0>

# %%
ga_resize = ga.deepcopy()
ga_resize.resize(ratio=1.5)

assert ga_resize.w==300
assert ga_resize.nlayer==2

ga_resize.pil
# Out:
# <PIL.Image.Image image mode=LA size=300x384 at 0x10F869340>

# %%
g_resize = g.deepcopy()
g_resize.resize(ratio=1.5)

assert g_resize.w==300
assert g_resize.nlayer==0

g_resize.pil
# Out:
# <PIL.Image.Image image mode=L size=300x384 at 0x10EB72D60>

# %% [markdown]
# # Spatial freuqnecy filtering

# %%
# show the original image
color.pil
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=200x256 at 0x10F53BFD0>

# %%
colorl = color.deepcopy()
colorl.sffilter()
plt.imshow(colorl.mat, cmap='gray')

# %%
colorh = color.deepcopy()
colorh.sffilter(sffilter='high')
plt.imshow(colorh.mat, cmap='gray')

# %% [markdown]
# # Phase scrambled

# %%
color_ps = color.deepcopy()
color_ps.mkphasescr()
color_ps.pil
# Out:
# <PIL.Image.Image image mode=RGBA size=200x256 at 0x12B838B50>

# %%
rgba_ps = rgba.deepcopy()
rgba_ps.mkphasescr()
rgba_ps.pil
# Out:
# /Users/hj23/opt/miniconda3/lib/python3.9/site-packages/pyfaceimage/im.py:381: RuntimeWarning: invalid value encountered in true_divide
#   mat = (mat - np.mean(mat))/np.std(mat) * rms
# <PIL.Image.Image image mode=RGBA size=200x256 at 0x12B7A8E20>

# %%
rgb_ps = rgb.deepcopy()
rgb_ps.mkphasescr()
rgb_ps.pil
# Out:
# <PIL.Image.Image image mode=RGB size=200x256 at 0x12B75B820>

# %%
ga_ps = ga.deepcopy()
ga_ps.mkphasescr()
ga_ps.pil
# Out:
# /Users/hj23/opt/miniconda3/lib/python3.9/site-packages/pyfaceimage/im.py:381: RuntimeWarning: invalid value encountered in true_divide
#   mat = (mat - np.mean(mat))/np.std(mat) * rms
# <PIL.Image.Image image mode=LA size=200x256 at 0x12B7877C0>

# %%
g_ps = g.deepcopy()
g_ps.mkphasescr()
g_ps.pil
# Out:
# <PIL.Image.Image image mode=L size=200x256 at 0x12B8AD9A0>
