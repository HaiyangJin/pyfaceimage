# %%
import os
import pyfaceimage as fim

# %%
stimdict = fim.dir('multi')
# Out:
# Found 4 files...

# %%
bsdict = fim.deepcopy(stimdict)
fim.mkboxscr(bsdict)

fim.sample(bsdict).pil
# Out:
# <PIL.Image.Image image mode=RGBA size=200x256 at 0x10560FF40>
